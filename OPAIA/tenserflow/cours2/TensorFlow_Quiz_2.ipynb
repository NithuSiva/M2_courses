# %% [markdown]
# # Quiz: Fundamentals with Neural Networks
#
# ### Question 1: What does the `Dense` layer do in a neural network?
#    - a) Adds dropout regularization to the network.
#    - b) Adds a fully connected layer where each neuron is connected to every neuron in the previous layer.
#    - c) Implements convolutional operations.
#    - d) Applies pooling operations.
#
# # Réponse
# b
#
# ### Question 2: Why is the `relu` activation function used in the hidden layers?
#    - a) To prevent negative outputs.
#    - b) To introduce non-linearity and help with the vanishing gradient problem.
#    - c) To ensure outputs are between 0 and 1.
#    - d) To apply a linear transformation to the inputs.
#
# # Réponse
# b
#
# ### Question 3: What is the purpose of `model.compile` in the code?
#    - a) To define the structure of the neural network.
#    - b) To configure the model for training by specifying the optimizer and loss function.
#    - c) To initialize the weights of the neural network.
#    - d) To load pre-trained weights into the model.
#
# # Réponse
# b
#
# ### Question 4: Which optimizer is used in the code, and why might it be chosen?
#    - a) SGD, because it is simple and easy to implement.
#    - b) Adam, because it adapts the learning rate and converges faster.
#    - c) RMSprop, because it is effective for recurrent neural networks.
#    - d) Adagrad, because it adjusts the learning rate based on the frequency of parameter updates.
#
# # Réponse
# b
#
#
# ### Question 5: What does the `model.fit` function do?
#    - a) Evaluates the model on the training data.
#    - b) Trains the model using the provided training data.
#    - c) Compiles the model for training.
#    - d) Saves the trained model to a file.
#
# # Réponse
# b
#
#
# ### Question 6: Why are angles converted to radians in the code?
#    - a) Because the `np.radians` function requires angles in radians.
#    - b) Because trigonometric functions in NumPy expect angles in radians.
#    - c) Because radians are the standard unit for all measurements.
#    - d) Because it simplifies the calculations.
#
# # Réponse
# b
#
#
# ### Question 7: What does the `verbose=0` parameter in `model.fit` do?
#    - a) Enables detailed logging of the training process.
#    - b) Disables logging output during the training process.
#    - c) Saves the training logs to a file.
#    - d) Shows only the final training loss.
#
# # Réponse
# b
#
#
# ### Question 8: What is the purpose of `plt.axis('off')` in the plotting section?
#    - a) To enable grid lines on the plot.
#    - b) To remove the axes for a cleaner visualization.
#    - c) To set the axis limits.
#    - d) To display the plot in 3D.
#
# # Réponse
# b
#
#
# ### Question 9: What is the shape of the input data for the neural network?
#    - a) A 2D array with one row per sample and one column per feature.
#    - b) A 3D array with one dimension for time.
#    - c) A 4D array for images.
#    - d) A 1D array with the shape determined by `input_shape' = [1].
#
# # Réponse
# a
#
# ### Question 10: What is the primary purpose of the `mean_squared_error` loss function in this context?
#     - a) To classify the input data into different categories.
#     - b) To measure the difference between the predicted and actual values.
#     - c) To normalize the input data.
#     - d) To apply a regularization term to the loss.
#
# # Réponse
# b
