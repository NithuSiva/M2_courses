# %% [markdown]
# ### Quiz for TensorFlow Regression Course
#
#
# **Question 1:**
# What is the primary difference between regression and classification problems?
#
# A) Regression predicts continuous variables, while classification predicts discrete classes.
#
# B) Regression is used for images, while classification is used for text.
#
# C) Regression models are always linear, while classification models are always non-linear.
#
# D) Regression requires more data preprocessing than classification.
#
# ---
#
# **Question 2:**
# In the context of the Auto MPG dataset, which feature is the target variable we aim to predict?
#
# A) Cylinders
#
# B) Displacement
#
# C) MPG
#
# D) Weight
#
# ---
#
# **Question 3:**
# What is the purpose of one-hot encoding the 'Origin' column in the Auto MPG dataset?
#
# A) To convert the categorical data into a numerical format suitable for the model.
#
# B) To normalize the data.
#
# C) To handle missing values in the dataset.
#
# D) To reduce the dimensionality of the dataset.
#
# ---
#
# **Question 4:**
# Why is it important to normalize features when training a neural network model?
#
# A) To increase the model's complexity.
#
# B) To ensure that features have the same scale and improve training stability.
#
# C) To reduce the size of the dataset.
#
# D) To make the features binary.
#
# ---
#
# **Question 5:**
# What is the purpose of using the tf.keras.layers.Normalization layer in a model?
#
# A) To apply dropout regularization.
#
# B) To normalize the input features to have a mean of 0 and a standard deviation of 1.
#
# C) To create dense connections between layers.
#
# D) To one-hot encode the categorical variables.
#
# ---
#
# **Question 6:**
# How do you compile a Keras model for training?
#
# A) Using the model.fit() method.
#
# B) Using the model.add() method.
#
# C) Using the model.compile() method.
#
# D) Using the model.evaluate() method.
#
# ---
#
# **Question 7:**
# Which optimizer is used in the single-variable linear regression model example?
#
# A) SGD
#
# B) RMSprop
#
# C) Adam
#
# D) Adagrad
#
# ---
#
# **Question 8:**
# What does the validation_split parameter do when training a Keras model?
#
# A) It specifies the percentage of the training data to be used for validation.
#
# B) It splits the dataset into training and testing sets.
#
# C) It shuffles the training data.
#
# D) It sets the batch size for training.
#
# ---
#
# **Question 9:**
# In the multi-variable linear regression example, what is the purpose of adding an additional Dense layer before the output layer?
#
# A) To increase the model's capacity to learn complex patterns.
#
# B) To reduce the model's complexity.
#
# C) To normalize the input features.
#
# D) To apply dropout regularization.
#
# ---
#
# **Question 10:**
# What is the purpose of L2 regularization in a neural network model?
#
# A) To increase the learning rate.
#
# B) To prevent overfitting by penalizing large weights.
#
# C) To apply dropout to the model.
#
# D) To reduce the number of layers in the model.
#
# ---
#
# **Question 11:**
# What does k-fold cross-validation help to achieve in model evaluation?
#
# A) It increases the size of the training dataset.
#
# B) It helps to ensure the model generalizes well by averaging performance over multiple folds.
#
# C) It reduces the model training time.
#
# D) It simplifies the model architecture.
#
# ---
#
# **Question 12:**
# What library is used to create visualizations in the TensorFlow regression tutorial?
#
# A) Matplotlib
#
# B) Seaborn
#
# C) Plotly
#
# D) Bokeh
#
# ---
#
# **Question 13:**
# How can you save a trained Keras model to a file?
#
# A) Using the model.fit() method.
#
# B) Using the model.save() method.
#
# C) Using the model.compile() method.
#
# D) Using the model.evaluate() method.
#
# ---
#
# **Question 14:**
# What is the purpose of using the Keras Tuner in model training?
#
# A) To visualize the model architecture.
#
# B) To automate the process of hyperparameter tuning.
#
# C) To increase the size of the training dataset.
#
# D) To reduce the number of training epochs.
#
# ---
#
# **Question 15:**
# What is the typical shape of the weight matrix in a single-variable linear regression model with one input feature and one output?
#
# A) (1, 1)
#
# B) (1, 2)
#
# C) (2, 1)
#
# D) (None, 1)
#
# ---
