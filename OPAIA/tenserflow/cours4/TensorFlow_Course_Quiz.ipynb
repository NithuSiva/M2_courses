# %% [markdown]
# ## Quiz : Images classification
#
# ### Question 1. What is the purpose of the `class_names` list in the code?
#    - a) To store the image data.
#    - b) To store the labels of the classes.
#    - c) To normalize the images.
#    - d) To augment the images.
#
# # Réponse
# b
#
# ### Question 2. What is the role of the `tf.keras.layers.Flatten` layer in the model?
#    - a) To apply activation functions.
#    - b) To normalize the images.
#    - c) To convert the 2D images into a 1D vector.
#    - d) To reduce the number of parameters.
#
# # Réponse
# c
#
# ### Question 3. What loss function is used in the model compilation?
#    - a) Mean Squared Error
#    - b) Categorical Crossentropy
#    - c) Sparse Categorical Crossentropy
#    - d) Binary Crossentropy
#
# # Réponse
# c
#
# ### Question 4. What is the shape of the input to the `tf.keras.layers.Dense(10)` layer?
#    - a) (28, 28)
#    - b) (128,)
#    - c) (784,)
#    - d) (10,)
#
# # Réponse
# d
#
# ### Question 5. What metric is used to evaluate the model's performance?
#    - a) Loss
#    - b) Accuracy
#    - c) Precision
#    - d) Recall
#
# # Réponse
# b
#
# ### Question 6. What does the method `model.fit()` return?
#    - a) The trained model
#    - b) The evaluation metrics
#    - c) A History object
#    - d) The predictions
#
# # Réponse
# c
#
# ### Question 7. Which method is used to evaluate the model on the test dataset?
#    - a) model.fit()
#    - b) model.evaluate()
#    - c) model.predict()
#    - d) model.compile()
#
# # Réponse
# b
#
# ### Question 8. How are the predictions made for the test dataset?
#    - a) Using the `model.fit()` method
#    - b) Using the `model.evaluate()` method
#    - c) Using the `model.predict()` method
#    - d) Using the `model.summary()` method
#
# # Réponse
# c
#
# ### Question 9. Why is a Softmax layer added after the original model?
#    - a) To apply dropout to the model.
#    - b) To convert the output logits to probabilities.
#    - c) To compile the model.
#    - d) To normalize the input images.
#
# # Réponse
# b
