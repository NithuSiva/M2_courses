# %% [markdown]
# # Quiz: Understanding Neural Networks and TensorFlow
#
# ### Question 1. What is the primary purpose of the Flatten layer in a neural network model?
#
# a) To add non-linearity to the model
# b) To convert 2D arrays into 1D arrays
# c) To prevent overfitting
# d) To perform data normalization
#
# # Réponse
# b
#
# ### Question 2. Which optimizer is being used in the provided code?
#
# a) SGD
# b) RMSprop
# c) Adam
# d) Adagrad
#
# # Réponse
# c
#
# ### Question 3. What does the Dropout layer do in a neural network?
#
# a) It scales the input data
# b) It adds non-linearity to the model
# c) It adds regularization by randomly setting a fraction of input units to 0
# d) It initializes the weights of the network
#
# # Réponse
# c
#
# ### Question 4. Why do we normalize the input data by dividing by 255.0?
#
# a) To reduce the computational load
# b) To prepare the data for softmax activation
# c) To increase the image resolution
# d) To convert the values to a range of 0 to 1
#
# # Réponse
# d
#
# ### Question 5. What is the purpose of using SparseCategoricalCrossentropy as the loss function?
#
# a) To handle multi-class classification problems with integer labels
# b) To compute the mean squared error
# c) To perform binary classification
# d) To minimize the difference between predicted and actual values
#
# # Réponse
# a
#
# ### Question 6. In the context of the provided code, what does the Softmax layer added at the end of the model do?
#
# a) It normalizes the input features
# b) It converts logits to probabilities
# c) It adds regularization to the model
# d) It performs dimensionality reduction
#
# # Réponse
# b
#
# ### Question 7. What is the role of the EarlyStopping callback in training neural networks?
#
# a) To speed up the training process
# b) To normalize the input data
# c) To initialize the weights of the network
# d) To prevent overfitting by stopping training when the validation loss stops improving
#
# # Réponse
# d
#
# ### Question 8. Which dataset is used in the provided code?
#
# a) CIFAR-10
# b) Fashion MNIST
# c) ImageNet
# d) MNIST
#
# # Réponse
# d
