# %% [markdown]
# # TensorFlow Text Classification Quiz
#
# **Question 1:**
# What is the purpose of text classification in machine learning?
#
# A) To convert text into numerical data
#
# B) To categorize text into predefined classes
#
# C) To generate new text based on given input
#
# D) To translate text from one language to another
#
# # Réponse
# b
# ---
#
# **Question 2:**
# What does the `text_dataset_from_directory` utility function do?
#
# A) Downloads a dataset from the internet
#
# B) Loads text files from a directory and prepares them for training
#
# C) Converts text data into numerical data
#
# D) Splits data into training and validation sets
#
# # Réponse
# b
# ---
#
# **Question 3:**
# Why do we use a `TextVectorization` layer in the model?
#
# A) To standardize and tokenize the text data
#
# B) To increase the size of the dataset
#
# C) To reduce the dimensionality of the data
#
# D) To create word embeddings
#
# # Réponse
# a
# ---
#
# **Question 4:**
# What is the purpose of the `Dropout` layer in the neural network?
#
# A) To convert text into numerical data
#
# B) To randomly set input units to 0 to prevent overfitting
#
# C) To pool the data and reduce its dimensionality
#
# D) To apply an activation function to the data
#
# # Réponse
# b
# ---
#
# **Question 5:**
# Which activation function is used in the final layer of the binary classification model?
#
# A) ReLU
#
# B) Tanh
#
# C) Softmax
#
# D) Sigmoid
#
# # Réponse
# d
# ---
#
# **Question 6:**
# What does the `EarlyStopping` callback do during model training?
#
# A) Stops training when a specified accuracy is reached
#
# B) Increases the learning rate if the model performance does not improve
#
# C) Stops training when the validation loss does not improve for a number of epochs
#
# D) Reduces the batch size if the model performance does not improve
#
# # Réponse
# c
# ---
#
# **Question 7:**
# Which TensorFlow function is used to create a dataset from text files in a directory?
#
# A) `tf.data.TextLineDataset`
#
# B) `tf.keras.preprocessing.text_dataset_from_directory`
#
# C) `tf.keras.utils.text_dataset_from_directory`
#
# D) `tf.data.Dataset.from_tensor_slices`
#
# # Réponse
# c
# ---
#
# **Question 8:**
# How can you visualize the training and validation accuracy and loss over time?
#
# A) By using TensorBoard
#
# B) By using the `plot` function from Matplotlib
#
# C) By printing the history object directly
#
# D) By exporting the results to a CSV file and plotting them in Excel
#
# # Réponse
# a
# ---
#
# **Question 9:**
# What is the primary purpose of the `GlobalAveragePooling1D` layer in the model?
#
# A) To apply an activation function to the data
#
# B) To convert variable-length sequences into fixed-length vectors
#
# C) To reduce the number of parameters in the model
#
# D) To add regularization to the model
#
# # Réponse
# b
# ---
#
# **Question 10:**
# What is the effect of increasing the batch size during training?
#
# A) It generally reduces the training time per epoch but may require more memory
#
# B) It increases the training time per epoch and requires less memory
#
# C) It has no effect on the training process
#
# D) It always improves the model's performance
#
# # Réponse
# a
# ---
#
# **Question 11:**
# What is the main benefit of using the `.cache()` and `.prefetch()` methods when loading data?
#
# A) To increase the size of the dataset
#
# B) To ensure that I/O does not become a bottleneck during training
#
# C) To reduce the dimensionality of the data
#
# D) To apply different preprocessing techniques to each set
#
# # Réponse
# b
# ---
#
# **Question 13:**
# Why is it important to shuffle the training data before each epoch?
#
# A) To ensure that the validation data is representative
#
# B) To help the model generalize better by preventing it from learning the order of the data
#
# C) To reduce the size of the dataset
#
# D) To apply different preprocessing techniques to each set
#
# # Réponse
# b
# ---
#
# **Question 14:**
# Which method would you use to evaluate the model on new, unseen data?
#
# A) `model.fit()`
#
# B) `model.predict()`
#
# C) `model.evaluate()`
#
# D) `model.compile()`
#
# # Réponse
#
# ---
#
# **Question 15:**
# What does the `prefetch` method do?
#
# A) Caches the dataset to memory
#
# B) Overlaps data preprocessing and model execution
#
# C) Shuffles the dataset
#
# D) Splits the dataset into training and validation sets
#
# # Réponse
# b
# ---
#
# **Question 16:**
# What is overfitting in the context of machine learning?
#
# A) When the model performs well on training data but poorly on validation/test data
#
# B) When the model performs well on both training and validation/test data
#
# C) When the model performs poorly on both training and validation/test data
#
# D) When the model has too few parameters
#
# # Réponse
# a
# ---
#
# **Question 17:**
# Which callback can be used to adjust the learning rate during training based on the performance of the model?
#
# A) `tf.keras.callbacks.EarlyStopping`
#
# B) `tf.keras.callbacks.ModelCheckpoint`
#
# C) `tf.keras.callbacks.LearningRateScheduler`
#
# D) `tf.keras.callbacks.TensorBoard`
#
# # Réponse
# c
# ---
