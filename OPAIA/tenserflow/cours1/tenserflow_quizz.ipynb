# %% [markdown]
# # Quiz: Understanding Data Loading and Visualization in TensorFlow
#
# ### Question 1. What is the purpose of the following line of code?
#
# 'x_train, x_test = x_train / 255.0, x_test / 255.0'
#
# A. To convert the images to grayscale
# B. To normalize the pixel values to the range [0, 1]
# C. To resize the images
# D. To denormalize the pixel values
#
# # Réponse
# b
#
# ### Question 2. Why is it important to split the data into training and test sets?
#
# A. To save memory
# B. To ensure the model is evaluated on unseen data
# C. To increase the dataset size
# D. To make training faster
#
# # Réponse
# b
#
# ### Question 3. How is the dataset URL defined in the code?
#
# A. As a local file path
# B. As a URL string
# C. As a Python dictionary
# D. As a TensorFlow constant
#
# # Réponse
# b
#
# ### Question 4. Which library is used for plotting and visualizing the images in this code?
#
# A. Seaborn
# B. Plotly
# C. Matplotlib
# D. TensorFlow
#
# # Réponse
# c
#
# ### Question 5. What function is used to load the CIFAR-10 dataset?
#
# A. `tf.keras.datasets.load_cifar10`
# B. `tf.keras.datasets.load_data`
# C. `tf.keras.datasets.cifar10.load_data`
# D. `tf.load_cifar10`
#
# # Réponse
# c
#
#
# ### Question 6. What does the `figsize` parameter in `plt.figure(figsize=(10,10))` specify?
#
# A. The size of the figure window in pixels
# B. The size of the figure window in inches
# C. The size of the figure window in centimeters
# D. The size of the figure window in points
#
# b
#
# ### Question 7. What is the shape of the `x_train` array after loading the CIFAR-10 dataset?
#
# A. (60000, 28, 28, 1)
# B. (50000, 32, 32, 3)
# C. (10000, 32, 32, 3)
# D. (50000, 28, 28, 3)
#
# # Réponse
# b
#
# ### Question 8. How is the CIFAR-10 dataset split?
#
# A. 60,000 training images and 10,000 test images
# B. 50,000 training images and 10,000 test images
# C. 40,000 training images and 20,000 test images
# D. 30,000 training images and 30,000 test images
#
# # Réponse
# b
