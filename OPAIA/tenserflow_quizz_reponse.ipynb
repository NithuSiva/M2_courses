# %% [markdown]
# # Quiz: TensorFlow Basics and Operations
#
# ### Question 1: What is TensorFlow?
# - a) A programming language
# - b) A library for numerical computation and machine learning
# - c) A type of neural network
# - d) An operating system
#
# # Réponse
# b
#
# ### Question 2: Which command is used to install TensorFlow using pip?
# - a) pip install tensorflow
# - b) install tensorflow
# - c) tensorflow install
# - d) pip tensorflow install
#
# # Réponse
# a
#
# ### Question 3: What is a tensor in TensorFlow?
# - a) A function
# - b) A multi-dimensional array
# - c) A scalar
# - d) A list
#
# # Réponse
# b
#
# ### Question 4: Which TensorFlow function is used to create a constant tensor?
# - a) tf.Variable
# - b) tf.constant
# - c) tf.placeholder
# - d) tf.ones
#
# # Réponse
# b
#
#
# ### Question 5: What is the rank of the tensor tf.constant([[1, 2], [3, 4]])?
# - a) 0
# - b) 1
# - c) 2
# - d) 3
#
# # Réponse
# c
#
# ### Question 6: Which of the following is NOT an operation you can perform directly on TensorFlow constants?
# - a) Addition
# - b) Subtraction
# - c) Division
# - d) Compilation
#
# # Réponse
# d
#
# ### Question 7: What does the following code do?
# ##### a = tf.constant(2)
# ##### b = tf.constant(3)
# ##### print(tf.add(a, b).numpy())
# - a) Adds two variables
# - b) Adds two constants and prints the result
# - c) Subtracts two constants and prints the result
# - d) Multiplies two constants and prints the result
#
# # Réponse
# b
#
# ### Question 8: In TensorFlow 2.x, which decorator is used to create a TensorFlow graph from a Python function?
# - a) @tf.graph
# - b) @tf.function
# - c) @tf.compute
# - d) @tf.layer
#
# # Réponse
# b
#
# ### Question 9: Which function would you use to add two TensorFlow variables?
# - a) tf.add
# - b) tf.Variable
# - c) tf.constant
# - d) tf.subtract
#
# # Réponse
# a
#
#
# ### Question 10: What is the output of the following code?
# ##### a = tf.constant(5)
# ##### b = tf.constant(4)
# ##### add = tf.add(a, b)
# ##### print(add.numpy())
# - a) 1
# - b) 9
# - c) 20
# - d) Error
#
# # Réponse
# b
#
# ### Question 11: Which TensorFlow function is used for matrix multiplication?
# - a) tf.add
# - b) tf.multiply
# - c) tf.matmul
# - d) tf.dot
#
# # Réponse
# c
#
#
# ### Question 12: What will be the shape of the resulting tensor after performing the following matrix multiplication?
# ##### matrix1 = tf.constant([[3., 3.]])
# ##### matrix2 = tf.constant([[2.], [2.]])
# ##### product = tf.matmul(matrix1, matrix2)
# - a) (1, 1)
# - b) (2, 2)
# - c) (1, 2)
# - d) (2, 1)
#
# # Réponse
# a
#
#
# ### Question 13: Which of the following operations would create a tensor of shape (2, 3) filled with zeros?
# - a) tf.constant([2, 3])
# - b) tf.zeros([2, 3])
# - c) tf.ones([2, 3])
# - d) tf.fill([2, 3], 0)
#
# # Réponse
# b
#
# ### Question 14: What does the following code do?
# ##### tensor = tf.constant([[1, 2, 3], [4, 5, 6]])
# ##### reshaped_tensor = tf.reshape(tensor, [3, 2])
# ##### print(reshaped_tensor.numpy())
# - a) Reshapes the tensor to a 3x2 matrix
# - b) Transposes the tensor
# - c) Flattens the tensor
# - d) Throws an error
#
# # Réponse
# a
#
#
# ### Question 15: How do you compute the sum of all elements in a tensor in TensorFlow?
# - a) tf.reduce_mean
# - b) tf.reduce_max
# - c) tf.reduce_sum
# - d) tf.reduce_min
#
# # Réponse
# c
